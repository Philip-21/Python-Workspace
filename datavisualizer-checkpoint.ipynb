# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#creating a simple plot
new_list = ([1,2,3,4,5,6,7,8,9])
next_list = ([11,12,33,45,66,77,88,34,15])
plt.plot(new_list, next_list)
plt.show()

# %%
#adding labels in the plot
new_list = ([1,2,3,4,5,6,7,8,9])
next_list = ([11,12,33,45,66,77,88,34,15])
plt.plot(new_list, next_list)
plt.xlabel('x numbers')
plt.ylabel('y numbers')
plt.show()

# %%
#Creating figures and axes to achieve the desired plot using state machione interface
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()

plt.show()

# %%
#Formatting the style of plot 
plt.plot([ 1, 2, 3, 4], [3, 4, 9, 16], 'go') #([x axis,yaxis the green dot show the point of intersection between the elements in eaxh of the axis  ])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
 # create a plot figure
plt.figure()

x1 = np.linspace(0, 10, 100)
# create the first of two panels and set current axis
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(x1, np.sin(x1))


# create the second of two panels and set current axis
plt.subplot(2, 1, 2)   # (rows, columns, panel number)
plt.plot(x1, np.cos(x1));

# %% [markdown]
# # HISTOGRAMS

# %%
 #plotting a simple histogram using plt.hist()

# %%
data = np.random.randn(500)
plt.hist(data)
# Out:
# (array([  9.,  20.,  62.,  95.,  97., 107.,  66.,  35.,   6.,   3.]),
#  array([-2.88375856, -2.27307731, -1.66239606, -1.05171481, -0.44103356,
#          0.16964769,  0.78032894,  1.39101018,  2.00169143,  2.61237268,
#          3.22305393]),
#  <BarContainer object of 10 artists>)

# %%
df = pd.read_csv('company_sales_data.csv')
df
# Out:
#    month  facecream  facewash  toothpaste  bathingsoap  shampoo  moisturizer  \
# 0    Jan       2500      1500        5200         9200     1200         1500
# 1    Feb       2630      1200        5100         6100     2100         1200
# 2    Mar       2140      1340        4550         9550     3550         1340
# 3    Apr       3400      1130        5870         8870     1870         1130
# 4    May       3600      1740        4560         7760     1560         1740
# 5    Jun       2760      1555        4890         7490     1890         1555
# 6    Jul       2980      1120        4780         8980     1780         1120
# 7    Aug       3700      1400        5860         9960     2860         1400
# 8    Sep       3540      1780        6100         8100     2100         1780
# 9    Oct       1990      1890        8300        10300     2300         1890
# 10   Nov       2340      2100        7300        13300     2400         2100
# ...

# %%
# Read Total profit of all months and show it using a line plot
new_list = df.get(['month_number'])
next_list = df.get(['total_profit'])
plt.plot(new_list, next_list)
plt.xlabel('month number')
plt.ylabel('profit made')
plt.title('COMPANY DATA OF THE YEAR')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-b9a585484e99> in <module>
#       2 new_list = df.get(['month_number'])
#       3 next_list = df.get(['total_profit'])
# ----> 4 plt.plot(new_list, next_list)
#       5 plt.xlabel('month number')
#       6 plt.ylabel('profit made')
#
# C:\Tools\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\Tools\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
# ...

# %% [markdown]
# # seaborn

# %%
next_figures =([12,34,18,13,23,15])
sns.distplot(next_figures)
plt.show()
# Out:
# C:\Tools\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # categorical scatter plots

# %%
#setting themes and colour plots 
sns.set_theme(style='ticks', color_codes=True)

# %%
df =pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.mean().plot(kind='bar')
#visualizing the mean of the datset
# Out:
# <AxesSubplot:>

# %%
#The approach used by stripplot(), which is the default “kind” in catplot() is to adjust the positions of
#points on the categorical axis  with a small amount of random “jitter”
sns.catplot(x='Sex', y='Age', data=df)

# %%
#The jitter parameter controls the magnitude of jitter or disables it altogether
sns.catplot(x='Sex', y='Age', jitter=False, data=df)

# %% [markdown]
# # Swarm  Plots

# %%
#The swarmplots representation gives  give a better representation of the distribution of observations,
# although it only works well for relatively #small datasets.it uses algorithms that prevent overlapping
sns.catplot(x='Sex', y='Age', kind='swarm', data=df)

# %% [markdown]
# # BoxPlots

# %%
sns.catplot(x='Sex', y='Age', kind='box', data=df)

# %%
sns.catplot(x='Pclass', y='Age', hue='Sex',kind='box', data=df)

# %% [markdown]
# # Boxen Plots

# %%
#A related function, boxenplot(), draws a plot that is similar to a box plot but optimized for showing 
#more information about the shape of the distribution. It is best suited for larger datasets
sns.catplot(x='Sex', y='Age', kind='boxen',data=df.sort_values("Sex"))

# %% [markdown]
# # ViolinPlots

# %%
#Violin plot combines a boxplot with the kernel density estimation 
sns.catplot(x='Pclass',y='Embarked',hue='Sex', kind='violin', data=df)

# %%
#splitting the violin plots when hue parameters have 2 levels to allow efficient use of Space
sns.catplot(x='Pclass', y='Age',hue='Sex', kind='violin',data=df,split=True)

# %%
#Combining Swarm plots and Violin plots
sns.violinplot(x='Sex',y='Age',data=df,hue='Sex',size=4)
sns.swarmplot(x='Sex', y='Age', data=df,hue='Sex',size=4)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # BARCHARTS

# %%
df1 =pd.read_csv('train.csv')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.barplot(x='Pclass', y='Age', data=df1)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
#adding hue to barplots
sns.barplot(x='Pclass', y='Age',data=df1, hue='Sex' )
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
df =pd.read_csv('company_sales_data.csv')
df
# Out:
#    month  facecream  facewash  toothpaste  bathingsoap  shampoo  moisturizer  \
# 0    Jan       2500      1500        5200         9200     1200         1500
# 1    Feb       2630      1200        5100         6100     2100         1200
# 2    Mar       2140      1340        4550         9550     3550         1340
# 3    Apr       3400      1130        5870         8870     1870         1130
# 4    May       3600      1740        4560         7760     1560         1740
# 5    Jun       2760      1555        4890         7490     1890         1555
# 6    Jul       2980      1120        4780         8980     1780         1120
# 7    Aug       3700      1400        5860         9960     2860         1400
# 8    Sep       3540      1780        6100         8100     2100         1780
# 9    Oct       1990      1890        8300        10300     2300         1890
# 10   Nov       2340      2100        7300        13300     2400         2100
# ...

# %%
sns.barplot(x='month', y='facecream',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='facecream'>

# %%
#catplot() is used when you want to show the number of observations in each category 
sns.countplot(y='Pclass', data=df1)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Pclass'>

# %% [markdown]
# # Point plots

# %%
sns.pointplot(x='Pclass',y='Age',hue='Sex', data=df1)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
sns.pointplot(x='Pclass',y='Age',markers=["^", "o"], linestyles=["-", "--"],data=df1)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>
